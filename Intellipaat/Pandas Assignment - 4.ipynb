# %% [markdown]
# Problem Statement:
# You work in XYZ Corporation as a Data Analyst. Your corporation has told you to analyze the
# customer_churn dataset with various functions.
# 1. Now from the churn data frame, try to sort the data by the tenure column according to the
# descending order.
# 2. Fetch all the records that are satisfying the following condition:
# a. Tenure>50 and the gender as ‘Female’.
# b. Gender as ‘Male’ and SeniorCitizen as 0.
# c. TechSupport as ‘Yes’ and Churn as ‘No’.
# d. Contract type as ‘Month-to-month’ and Churn as‘Yes’.

# %%
import pandas as pd
df1=pd.read_csv(r'B:\MY COMPUTER (HOME)\2 IT\Intellipaat course\python with data science\assignments\pandas\ASSIGNMENT-4-8211-PANDAS-05AUG2022121849\customer_churn-3.csv')
print(df.head())
print('\n\n',df.describe())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]
#
#
#         SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
# 1. Now from the churn data frame, try to sort the data by the tenure column according to the descending order.
df1.sort_values(by=['tenure'],ascending=[False])
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1672  4737-AQCPU    Male              0     Yes        Yes      72
# 193   9680-NIAUV  Female              0     Yes        Yes      72
# 4553  5914-XRFQB    Male              0     Yes         No      72
# 483   5168-MQQCA  Female              0     Yes         No      72
# 3266  0464-WJTKO  Female              0     Yes        Yes      72
# ...          ...     ...            ...     ...        ...     ...
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1672          Yes               Yes             DSL                  Yes  ...
# 193           Yes               Yes     Fiber optic                  Yes  ...
# 4553          Yes               Yes     Fiber optic                  Yes  ...
# 483           Yes               Yes     Fiber optic                   No  ...
# 3266          Yes                No              No  No internet service  ...
# ...           ...               ...             ...                  ...  ...
# 1082          Yes               Yes              No  No internet service  ...
# 3826          Yes               Yes              No  No internet service  ...
# 936           Yes                No             DSL                  Yes  ...
# 6754          Yes               Yes             DSL                  Yes  ...
# 1340           No  No phone service             DSL                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 1672                  Yes                  Yes                   No
# 193                   Yes                   No                  Yes
# 4553                  Yes                  Yes                  Yes
# 483                   Yes                  Yes                  Yes
# 3266  No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 1082  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 936                   Yes                   No                  Yes
# 6754                   No                  Yes                   No
# 1340                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling  \
# 1672                   No  Two year               No
# 193                   Yes  Two year               No
# 4553                  Yes  Two year              Yes
# 483                   Yes  One year              Yes
# 3266  No internet service  Two year               No
# ...                   ...       ...              ...
# 1082  No internet service  Two year               No
# 3826  No internet service  Two year               No
# 936                   Yes  Two year               No
# 6754                   No  Two year              Yes
# 1340                   No  Two year               No
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 1672    Credit card (automatic)          72.10       5016.65    No
# 193     Credit card (automatic)         109.70        8129.3    No
# 4553  Bank transfer (automatic)         115.80        8424.9    No
# 483   Bank transfer (automatic)         108.50        8003.8    No
# 3266  Bank transfer (automatic)          20.10       1460.85    No
# ...                         ...            ...           ...   ...
# 1082               Mailed check          25.75                  No
# 3826               Mailed check          25.35                  No
# 936                Mailed check          80.85                  No
# 6754  Bank transfer (automatic)          61.90                  No
# 1340    Credit card (automatic)          56.05                  No
#
# [7043 rows x 21 columns]

# %%
# Fetch all the records that are satisfying the following condition: 
# a. Tenure>50 and the gender as ‘Female’. 
df1[df1['tenure']>50 & df1['gender'] == 'female']

# b. Gender as ‘Male’ and SeniorCitizen as 0. 
df1[df1['SeniorCitizen']==0 & df1['gender'] == 'male']

# c. TechSupport as ‘Yes’ and Churn as ‘No’. 
df1[df1['TechSupport']=='yes' & df1['Churn'] == 'no']

#d. Contract type as ‘Month-to-month’ and Churn as‘Yes’.
df1[df1['Contract type']=='Month-to-month' & df1['Churn'] == 'Yes']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 14>()
#       1 # # Fetch all the records that are satisfying the following condition:
#       2 # # a. Tenure>50 and the gender as ‘Female’.
#       3 # df1[df1['tenure']>50 & df1['gender'] == 'female']
#    (...)
#      11 # #d. Contract type as ‘Month-to-month’ and Churn as‘Yes’.
#      12 # df1[df1['Contract type']=='Month-to-month' & df1['Churn'] == 'Yes']
# ---> 14 df1=pd.read_csv(r'B:\MY COMPUTER (HOME)\2 IT\Intellipaat course\python with data science\assignments\pandas\ASSIGNMENT-4-8211-PANDAS-05AUG2022121849\customer_churn-3.csv',  usecols='tenure')
#      15 print(df1)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1235, in TextFileReader._make_engine(self, f, engine)
#    1232     raise ValueError(msg)
#    1234 try:
# -> 1235     return mapping[engine](f, **self.options)
#    1236 except Exception:
#    1237     if self.handles is not None:
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:46, in CParserWrapper.__init__(self, src, **kwds)
#      45 def __init__(self, src: ReadCsvBuffer[str], **kwds):
# ---> 46     super().__init__(kwds)
#      47     self.kwds = kwds
#      48     kwds = kwds.copy()
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:170, in ParserBase.__init__(self, kwds)
#     166 self._name_processed = False
#     168 self._first_chunk = True
# --> 170 self.usecols, self.usecols_dtype = self._validate_usecols_arg(kwds["usecols"])
#     172 # Fallback to error to pass a sketchy test(test_override_set_noconvert_columns)
#     173 # Normally, this arg would get pre-processed earlier on
#     174 self.on_bad_lines = kwds.get("on_bad_lines", self.BadLineHandleMethod.ERROR)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:957, in ParserBase._validate_usecols_arg(self, usecols)
#     951     return usecols, None
#     953 if not is_list_like(usecols):
#     954     # see gh-20529
#     955     #
#     956     # Ensure it is iterable container but not string.
# --> 957     raise ValueError(msg)
#     959 usecols_dtype = lib.infer_dtype(usecols, skipna=False)
#     961 if usecols_dtype not in ("empty", "integer", "string"):
#
# ValueError: 'usecols' must either be list-like of all strings, all unicode, all integers or a callable.
